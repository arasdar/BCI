# %% [markdown]
# # DL Brain project

# %%
# %ls /home/arasdar/datasets/DL-BrainBody/Control/
# Out:
# O10test1.txt   O2valid3.txt  O4valid2.txt  O6valid1.txt  O8train.txt
# O10test2.txt   O3test1.txt   O4valid3.txt  O6valid2.txt  O8valid1.txt
# O10test3.txt   O3test2.txt   O5test1.txt   O6valid3.txt  O8valid2.txt
# O10train.txt   O3test3.txt   O5test2.txt   O7test1.txt   O8valid3.txt
# O10valid1.txt  O3train.txt   O5test3.txt   O7test2.txt   O9test1.txt
# O10valid2.txt  O3valid1.txt  O5train.txt   O7test3.txt   O9test2.txt
# O10valid3.txt  O3valid2.txt  O5valid1.txt  O7train.txt   O9test3.txt
# O2test1.txt    O3valid3.txt  O5valid2.txt  O7valid1.txt  O9train.txt
# O2test2.txt    O4test1.txt   O5valid3.txt  O7valid2.txt  O9valid1.txt
# O2test3.txt    O4test2.txt   O6test1.txt   O7valid3.txt  O9valid2.txt
# O2train.txt    O4test3.txt   O6test2.txt   O8test1.txt   O9valid3.txt
# O2valid1.txt   O4train.txt   O6test3.txt   O8test2.txt
# O2valid2.txt   O4valid1.txt  O6train.txt   O8test3.txt

# %%
# %ls /home/arasdar/datasets/DL-BrainBody/PD/
# Out:
# P10test1.txt   P11valid3.txt  P4valid2.txt  P6valid1.txt  P8train.txt
# P10test2.txt   P1test1.txt    P4valid3.txt  P6valid2.txt  P8valid1.txt
# P10test3.txt   P1test2.txt    P5test1.txt   P6valid3.txt  P8valid2.txt
# P10train.txt   P1test3.txt    P5test2.txt   P7test1.txt   P8valid3.txt
# P10valid1.txt  P1train.txt    P5test3.txt   P7test2.txt   P9test1.txt
# P10valid2.txt  P1valid1.txt   P5train.txt   P7test3.txt   P9test2.txt
# P10valid3.txt  P1valid2.txt   P5valid1.txt  P7train.txt   P9test3.txt
# P11test1.txt   P1valid3.txt   P5valid2.txt  P7valid1.txt  P9train.txt
# P11test2.txt   P4test1.txt    P5valid3.txt  P7valid2.txt  P9valid1.txt
# P11test3.txt   P4test2.txt    P6test1.txt   P7valid3.txt  P9valid2.txt
# P11train.txt   P4test3.txt    P6test2.txt   P8test1.txt   P9valid3.txt
# P11valid1.txt  P4train.txt    P6test3.txt   P8test2.txt
# P11valid2.txt  P4valid1.txt   P6train.txt   P8test3.txt

# %%
import numpy as np
import pandas as pd
############################################# Training ##############################################################
############################################# Training ##############################################################
############################################# Training ##############################################################
Xctr2 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O2train.txt', header=None, 
                        delim_whitespace=True)
Xctr3 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O3train.txt', header=None, 
                        delim_whitespace=True)
Xctr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O4train.txt', header=None, 
                        delim_whitespace=True)
Xctr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O5train.txt', header=None, 
                        delim_whitespace=True)
Xctr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O6train.txt', header=None, 
                        delim_whitespace=True)
Xctr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O7train.txt', header=None, 
                        delim_whitespace=True)
Xctr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O8train.txt', header=None, 
                        delim_whitespace=True)
Xctr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O9train.txt', header=None, 
                        delim_whitespace=True)
Xctr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O10train.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xptr1 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P1train.txt', header=None, 
                        delim_whitespace=True)
Xptr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P4train.txt', header=None, 
                        delim_whitespace=True)
Xptr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P5train.txt', header=None, 
                        delim_whitespace=True)
Xptr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P6train.txt', header=None, 
                        delim_whitespace=True)
Xptr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P7train.txt', header=None, 
                        delim_whitespace=True)
Xptr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P8train.txt', header=None, 
                        delim_whitespace=True)
Xptr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P9train.txt', header=None, 
                        delim_whitespace=True)
Xptr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P10train.txt', header=None, 
                        delim_whitespace=True)
Xptr11 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P11train.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xctr = np.array([Xctr2.values, Xctr3.values, Xctr4.values, Xctr5.values, Xctr6.values, Xctr7.values, Xctr8.values, 
                 Xctr9.values, Xctr10.values])
Xptr = np.array([Xptr1.values, Xptr4.values, Xptr5.values, Xptr6.values, Xptr7.values, Xptr8.values, Xptr9.values, 
                 Xptr10.values, Xptr11.values])
Xtr = np.concatenate([Xctr, Xptr], axis=0)
# 'Training data:', Xctr.shape, Xptr.shape, \
# Xctr.dtype, Xptr.dtype, \
print(Xtr.shape, Xtr.reshape(18, -1, 8, 256, 56).shape)
############################################# Validation1 ##############################################################
############################################# Validation1 ##############################################################
############################################# Validation1 ##############################################################
Xctr2 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O2valid1.txt', header=None, 
                        delim_whitespace=True)
Xctr3 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O3valid1.txt', header=None, 
                        delim_whitespace=True)
Xctr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O4valid1.txt', header=None, 
                        delim_whitespace=True)
Xctr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O5valid1.txt', header=None, 
                        delim_whitespace=True)
Xctr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O6valid1.txt', header=None, 
                        delim_whitespace=True)
Xctr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O7valid1.txt', header=None, 
                        delim_whitespace=True)
Xctr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O8valid1.txt', header=None, 
                        delim_whitespace=True)
Xctr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O9valid1.txt', header=None, 
                        delim_whitespace=True)
Xctr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O10valid1.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xptr1 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P1valid1.txt', header=None, 
                        delim_whitespace=True)
Xptr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P4valid1.txt', header=None, 
                        delim_whitespace=True)
Xptr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P5valid1.txt', header=None, 
                        delim_whitespace=True)
Xptr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P6valid1.txt', header=None, 
                        delim_whitespace=True)
Xptr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P7valid1.txt', header=None, 
                        delim_whitespace=True)
Xptr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P8valid1.txt', header=None, 
                        delim_whitespace=True)
Xptr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P9valid1.txt', header=None, 
                        delim_whitespace=True)
Xptr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P10valid1.txt', header=None, 
                        delim_whitespace=True)
Xptr11 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P11valid1.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xcval = np.array([Xctr2.values, Xctr3.values, Xctr4.values, Xctr5.values, Xctr6.values, Xctr7.values, Xctr8.values,
                  Xctr9.values, Xctr10.values])
Xpval = np.array([Xptr1.values, Xptr4.values, Xptr5.values, Xptr6.values, Xptr7.values, Xptr8.values, Xptr9.values, 
                  Xptr10.values, Xptr11.values])
Xval1 = np.concatenate([Xcval, Xpval], axis=0)
# Xcval.shape, Xpval.shape, \
# Xcval.dtype, Xpval.dtype, \
print(Xval1.shape, Xval1.reshape(18, -1, 8, 256, 56).shape)
############################################# Validation2 ##############################################################
############################################# Validation2 ##############################################################
############################################# Validation2 ##############################################################
Xctr2 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O2valid2.txt', header=None, 
                        delim_whitespace=True)
Xctr3 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O3valid2.txt', header=None, 
                        delim_whitespace=True)
Xctr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O4valid2.txt', header=None, 
                        delim_whitespace=True)
Xctr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O5valid2.txt', header=None, 
                        delim_whitespace=True)
Xctr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O6valid2.txt', header=None, 
                        delim_whitespace=True)
Xctr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O7valid2.txt', header=None, 
                        delim_whitespace=True)
Xctr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O8valid2.txt', header=None, 
                        delim_whitespace=True)
Xctr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O9valid2.txt', header=None, 
                        delim_whitespace=True)
Xctr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O10valid2.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xptr1 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P1valid2.txt', header=None, 
                        delim_whitespace=True)
Xptr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P4valid2.txt', header=None, 
                        delim_whitespace=True)
Xptr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P5valid2.txt', header=None, 
                        delim_whitespace=True)
Xptr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P6valid2.txt', header=None, 
                        delim_whitespace=True)
Xptr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P7valid2.txt', header=None, 
                        delim_whitespace=True)
Xptr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P8valid2.txt', header=None, 
                        delim_whitespace=True)
Xptr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P9valid2.txt', header=None, 
                        delim_whitespace=True)
Xptr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P10valid2.txt', header=None, 
                        delim_whitespace=True)
Xptr11 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P11valid2.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xcval = np.array([Xctr2.values, Xctr3.values, Xctr4.values, Xctr5.values, Xctr6.values, Xctr7.values, Xctr8.values, 
                  Xctr9.values, Xctr10.values])
Xpval = np.array([Xptr1.values, Xptr4.values, Xptr5.values, Xptr6.values, Xptr7.values, Xptr8.values, Xptr9.values, 
                  Xptr10.values, Xptr11.values])
Xval2 = np.concatenate([Xcval, Xpval], axis=0)
# Xcval.shape, Xpval.shape, \
# Xcval.dtype, Xpval.dtype, \
print(Xval2.shape, Xval2.reshape(18, -1, 8, 256, 56).shape)
########################################### Validation3 ################################################################
########################################### Validation3 ################################################################
########################################### Validation3 ################################################################
Xctr2 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O2valid3.txt', header=None, 
                        delim_whitespace=True)
Xctr3 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O3valid3.txt', header=None, 
                        delim_whitespace=True)
Xctr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O4valid3.txt', header=None, 
                        delim_whitespace=True)
Xctr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O5valid3.txt', header=None, 
                        delim_whitespace=True)
Xctr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O6valid3.txt', header=None, 
                        delim_whitespace=True)
Xctr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O7valid3.txt', header=None, 
                        delim_whitespace=True)
Xctr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O8valid3.txt', header=None, 
                        delim_whitespace=True)
Xctr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O9valid3.txt', header=None, 
                        delim_whitespace=True)
Xctr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O10valid3.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xptr1 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P1valid3.txt', header=None, 
                        delim_whitespace=True)
Xptr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P4valid3.txt', header=None, 
                        delim_whitespace=True)
Xptr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P5valid3.txt', header=None, 
                        delim_whitespace=True)
Xptr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P6valid3.txt', header=None, 
                        delim_whitespace=True)
Xptr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P7valid3.txt', header=None, 
                        delim_whitespace=True)
Xptr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P8valid3.txt', header=None, 
                        delim_whitespace=True)
Xptr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P9valid3.txt', header=None, 
                        delim_whitespace=True)
Xptr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P10valid3.txt', header=None, 
                        delim_whitespace=True)
Xptr11 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P11valid3.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xcval = np.array([Xctr2.values, Xctr3.values, Xctr4.values, Xctr5.values, Xctr6.values, Xctr7.values, Xctr8.values, 
                  Xctr9.values, Xctr10.values])
Xpval = np.array([Xptr1.values, Xptr4.values, Xptr5.values, Xptr6.values, Xptr7.values, Xptr8.values, Xptr9.values, 
                  Xptr10.values, Xptr11.values])
Xval3 = np.concatenate([Xcval, Xpval], axis=0)
# Xcval.shape, Xpval.shape, \
# Xcval.dtype, Xpval.dtype, \
print(Xval3.shape, Xval3.reshape(18, -1, 8, 256, 56).shape)
########################################### Test1 ################################################################
########################################### Test1 ################################################################
########################################### Test1 ################################################################
Xctr2 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O2test1.txt', header=None, 
                        delim_whitespace=True)
Xctr3 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O3test1.txt', header=None, 
                        delim_whitespace=True)
Xctr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O4test1.txt', header=None, 
                        delim_whitespace=True)
Xctr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O5test1.txt', header=None, 
                        delim_whitespace=True)
Xctr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O6test1.txt', header=None, 
                        delim_whitespace=True)
Xctr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O7test1.txt', header=None, 
                        delim_whitespace=True)
Xctr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O8test1.txt', header=None, 
                        delim_whitespace=True)
Xctr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O9test1.txt', header=None, 
                        delim_whitespace=True)
Xctr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O10test1.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xptr1 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P1test1.txt', header=None, 
                        delim_whitespace=True)
Xptr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P4test1.txt', header=None, 
                        delim_whitespace=True)
Xptr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P5test1.txt', header=None, 
                        delim_whitespace=True)
Xptr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P6test1.txt', header=None, 
                        delim_whitespace=True)
Xptr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P7test1.txt', header=None, 
                        delim_whitespace=True)
Xptr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P8test1.txt', header=None, 
                        delim_whitespace=True)
Xptr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P9test1.txt', header=None, 
                        delim_whitespace=True)
Xptr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P10test1.txt', header=None, 
                        delim_whitespace=True)
Xptr11 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P11test1.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xcval = np.array([Xctr2.values, Xctr3.values, Xctr4.values, Xctr5.values, Xctr6.values, Xctr7.values, Xctr8.values, 
                  Xctr9.values, Xctr10.values])
Xpval = np.array([Xptr1.values, Xptr4.values, Xptr5.values, Xptr6.values, Xptr7.values, Xptr8.values, Xptr9.values, 
                  Xptr10.values, Xptr11.values])
Xtest1 = np.concatenate([Xcval, Xpval], axis=0)
# Xcval.shape, Xpval.shape, \
# Xcval.dtype, Xpval.dtype, \
print(Xtest1.shape, Xtest1.reshape(18, -1, 8, 256, 56).shape)
############################################ Test2 ###############################################################
############################################ Test2 ###############################################################
############################################ Test2 ###############################################################
Xctr2 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O2test2.txt', header=None, 
                        delim_whitespace=True)
Xctr3 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O3test2.txt', header=None, 
                        delim_whitespace=True)
Xctr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O4test2.txt', header=None, 
                        delim_whitespace=True)
Xctr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O5test2.txt', header=None, 
                        delim_whitespace=True)
Xctr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O6test2.txt', header=None, 
                        delim_whitespace=True)
Xctr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O7test2.txt', header=None, 
                        delim_whitespace=True)
Xctr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O8test2.txt', header=None, 
                        delim_whitespace=True)
Xctr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O9test2.txt', header=None, 
                        delim_whitespace=True)
Xctr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O10test2.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xptr1 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P1test2.txt', header=None, 
                        delim_whitespace=True)
Xptr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P4test2.txt', header=None, 
                        delim_whitespace=True)
Xptr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P5test2.txt', header=None, 
                        delim_whitespace=True)
Xptr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P6test2.txt', header=None, 
                        delim_whitespace=True)
Xptr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P7test2.txt', header=None, 
                        delim_whitespace=True)
Xptr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P8test2.txt', header=None, 
                        delim_whitespace=True)
Xptr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P9test2.txt', header=None, 
                        delim_whitespace=True)
Xptr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P10test2.txt', header=None, 
                        delim_whitespace=True)
Xptr11 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P11test2.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xcval = np.array([Xctr2.values, Xctr3.values, Xctr4.values, Xctr5.values, Xctr6.values, Xctr7.values, Xctr8.values, 
                  Xctr9.values, Xctr10.values])
Xpval = np.array([Xptr1.values, Xptr4.values, Xptr5.values, Xptr6.values, Xptr7.values, Xptr8.values, Xptr9.values, 
                  Xptr10.values, Xptr11.values])
Xtest2 = np.concatenate([Xcval, Xpval], axis=0)
# Xcval.shape, Xpval.shape, \
# Xcval.dtype, Xpval.dtype, \
print(Xtest2.shape, Xtest2.reshape(18, -1, 8, 256, 56).shape)
############################################# Test3 ##############################################################
############################################# Test3 ##############################################################
############################################# Test3 ##############################################################
Xctr2 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O2test3.txt', header=None, 
                        delim_whitespace=True)
Xctr3 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O3test3.txt', header=None, 
                        delim_whitespace=True)
Xctr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O4test3.txt', header=None, 
                        delim_whitespace=True)
Xctr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O5test3.txt', header=None, 
                        delim_whitespace=True)
Xctr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O6test3.txt', header=None, 
                        delim_whitespace=True)
Xctr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O7test3.txt', header=None, 
                        delim_whitespace=True)
Xctr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O8test3.txt', header=None, 
                        delim_whitespace=True)
Xctr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O9test3.txt', header=None, 
                        delim_whitespace=True)
Xctr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/Control/O10test3.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xptr1 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P1test3.txt', header=None, 
                        delim_whitespace=True)
Xptr4 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P4test3.txt', header=None, 
                        delim_whitespace=True)
Xptr5 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P5test3.txt', header=None, 
                        delim_whitespace=True)
Xptr6 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P6test3.txt', header=None, 
                        delim_whitespace=True)
Xptr7 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P7test3.txt', header=None, 
                        delim_whitespace=True)
Xptr8 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P8test3.txt', header=None, 
                        delim_whitespace=True)
Xptr9 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P9test3.txt', header=None, 
                        delim_whitespace=True)
Xptr10 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P10test3.txt', header=None, 
                        delim_whitespace=True)
Xptr11 = pd.read_csv(filepath_or_buffer='/home/arasdar/datasets/DL-BrainBody/PD/P11test3.txt', header=None, 
                        delim_whitespace=True)
###########################################################################################################
Xcval = np.array([Xctr2.values, Xctr3.values, Xctr4.values, Xctr5.values, Xctr6.values, Xctr7.values, Xctr8.values, 
                  Xctr9.values, Xctr10.values])
Xpval = np.array([Xptr1.values, Xptr4.values, Xptr5.values, Xptr6.values, Xptr7.values, Xptr8.values, Xptr9.values, 
                  Xptr10.values, Xptr11.values])
Xtest3 = np.concatenate([Xcval, Xpval], axis=0)
# Xcval.shape, Xpval.shape, \
# Xcval.dtype, Xpval.dtype, \
print(Xtest3.shape, Xtest3.reshape(18, -1, 8, 256, 56).shape)
# Out:
# (18, 81920, 56) (18, 40, 8, 256, 56)
# (18, 40960, 56) (18, 20, 8, 256, 56)
# (18, 40960, 56) (18, 20, 8, 256, 56)
# (18, 38912, 56) (18, 19, 8, 256, 56)
# (18, 79872, 56) (18, 39, 8, 256, 56)
# (18, 79872, 56) (18, 39, 8, 256, 56)
# (18, 81920, 56) (18, 40, 8, 256, 56)

# %%
seq_length = 256 # 4*256: 4 sec * 256 sample/sec
print(Xtr.shape, Xtr.reshape(18, -1, 8, seq_length, 56).shape)
print(Xval1.shape, Xval1.reshape(18, -1, 8, seq_length, 56).shape)
print(Xval2.shape, Xval2.reshape(18, -1, 8, seq_length, 56).shape)
print(Xval3.shape, Xval3.reshape(18, -1, 8, seq_length, 56).shape)
print(Xtest1.shape, Xtest1.reshape(18, -1, 8, seq_length, 56).shape)
print(Xtest2.shape, Xtest2.reshape(18, -1, 8, seq_length, 56).shape)
print(Xtest3.shape, Xtest3.reshape(18, -1, 8, seq_length, 56).shape)
# Out:
# (18, 81920, 56) (18, 40, 8, 256, 56)
# (18, 40960, 56) (18, 20, 8, 256, 56)
# (18, 40960, 56) (18, 20, 8, 256, 56)
# (18, 38912, 56) (18, 19, 8, 256, 56)
# (18, 79872, 56) (18, 39, 8, 256, 56)
# (18, 79872, 56) (18, 39, 8, 256, 56)
# (18, 81920, 56) (18, 40, 8, 256, 56)

# %%
seq_length = 256 # 4*256: 4 sec * 256 sample/sec
inputs_tr = Xtr.reshape([-1, 8, seq_length, 56])
inputs_val1 = Xval1.reshape([-1, 8, seq_length, 56])
inputs_val2 = Xval2.reshape([-1, 8, seq_length, 56])
inputs_val3 = Xval3.reshape([-1, 8, seq_length, 56])
inputs_test1 = Xtest1.reshape([-1, 8, seq_length, 56])
inputs_test2 = Xtest2.reshape([-1, 8, seq_length, 56])
inputs_test3 = Xtest3.reshape([-1, 8, seq_length, 56])
print(inputs_tr.shape, inputs_tr.dtype)
print(inputs_val1.shape, inputs_val1.dtype)
print(inputs_val2.shape, inputs_val2.dtype)
print(inputs_val3.shape, inputs_val3.dtype)
print(inputs_test1.shape, inputs_test1.dtype)
print(inputs_test2.shape, inputs_test2.dtype)
print(inputs_test3.shape, inputs_test3.dtype)
# Out:
# (720, 8, 256, 56) float64
# (360, 8, 256, 56) float64
# (360, 8, 256, 56) float64
# (342, 8, 256, 56) float64
# (702, 8, 256, 56) float64
# (702, 8, 256, 56) float64
# (720, 8, 256, 56) float64

# %%
Yctr = np.zeros(9) # control labels: False
Yptr = np.ones(9) # pd labels: True
indices = np.concatenate([Yctr, Yptr], axis=0)
print(indices.shape, indices.dtype)
# Out:
# (18,) float64

# %%
# In this one we should define and detect GPUs for tensorflow
# GPUs or CPU
import tensorflow as tf

# Check TensorFlow Version
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.11.0
# Default GPU Device: /device:GPU:0

# %%
batch_size = 18 # number of subjects
# seq_length = ? # dynamic_rnn (flexible) NOT static_rnn
input_size = (8, 256, 56) # one second of each activity which is 1024=256sample/sec*4sec
output_size = 2 # number of classes
hidden_size = 4 # LSTM-FC layer
learning_rate = 1e-4

# %%
def model_input(input_size, hidden_size, batch_size):
    # CNN and MLP
    inputs = tf.placeholder(dtype=tf.float32, shape=[None, *input_size], name='inputs')
    indices = tf.placeholder(dtype=tf.int32, shape=[None], name='indices')    
    training = tf.placeholder(dtype=tf.bool, shape=[], name='training') # batchnorm
    # RNN
    cell = tf.nn.rnn_cell.GRUCell(num_units=hidden_size)
    #cell = tf.nn.rnn_cell.LSTMCell(hidden_size)
    cells = tf.nn.rnn_cell.MultiRNNCell(cells=[cell], state_is_tuple=True)
    initial_state = cells.zero_state(batch_size, tf.float32) # ??? None/batch size
    return inputs, indices, training, cells, initial_state

# %%
def discriminator(inputs, input_size, output_size, # CNN
                  batch_size, initial_state, cells, # RNN/MLP/FC
                  alpha=0.1, training=False, reuse=False): # NL/BN
    with tf.variable_scope('discriminator', reuse=reuse):
        # CNN: NHWC format = (?, 8, 256, 56)
        print(inputs.shape)
        h1 = tf.layers.conv2d(inputs=inputs, filters=2, kernel_size=[8, 3], strides=[1, 16], padding='same')
        bn1 = tf.layers.batch_normalization(h1, training=training)
        nl1 = tf.maximum(alpha * bn1, bn1)
        print(nl1.shape)
        h1 = tf.layers.conv2d(inputs=nl1, filters=4, kernel_size=[8, 3], strides=[8, 16], padding='same')
        bn1 = tf.layers.batch_normalization(h1, training=training)
        nl1 = tf.maximum(alpha * bn1, bn1)
        print(nl1.shape)

        # RNN/MLP/Fully Connected: NDHWC =(?, ?, C)
        inputs_rnn = tf.reshape(tensor=nl1, shape=[batch_size, -1, 4]) # filters == hiddden_size
        print('inputs_rnn.shape, initial_state[0].shape', 
              inputs_rnn.shape, initial_state[0].shape) # tuple=True
        # uni-directional/bi-directional: dynamic/static on sequence length
        outputs_rnn, final_state = tf.nn.dynamic_rnn(cell=cells, inputs=inputs_rnn, initial_state=initial_state)
        print('outputs_rnn.shape, final_state[0].shape',
              outputs_rnn.shape, final_state[0].shape) # tuple=True
        #outputs = tf.reshape(outputs_rnn, [-1, hidden_size]) # ?x40, VEC
        outputs = outputs_rnn[:, -1] # ?, -1: each batch, the last timestep
        print('outputs.shape', outputs.shape)

        # Output layer
        logits = tf.layers.dense(inputs=outputs, units=output_size)
        print(logits.shape)
        return logits, final_state

# %%
def model_loss(inputs, indices, input_size, output_size, hidden_size, batch_size, cells, initial_state, training):
    logits, final_state = discriminator(inputs=inputs, input_size=input_size, output_size=output_size, 
                                        cells=cells, initial_state=initial_state, batch_size=batch_size, 
                                        training=training)
    labels = tf.one_hot(indices=indices, depth=output_size, dtype=logits.dtype)
    print(logits.shape, labels.shape)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=labels))
    # If argmax label and argmax logits are equal: true/false
    if_equal_bool = tf.equal(x=tf.argmax(axis=1, input=logits), y=tf.argmax(axis=1, input=labels))
    accuracy = tf.reduce_mean(axis=0, input_tensor=tf.cast(dtype=tf.float32, x=if_equal_bool))
    return loss, accuracy

# %%
def model_opt(loss, learning_rate):
    tvars = tf.trainable_variables()
    dvars = [var for var in tvars if var.name.startswith('discriminator')]
    # dvars = []
    # for var in tvars: 
    #     if var.name.startswith('discriminator'):
    #         dvars.append(var)
    
    # Optimize MLP/CNN
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)): # Required for batchnorm (BN)
        #grads, _ = tf.clip_by_global_norm(t_list=tf.gradients(loss, dvars), clip_norm=5) # usually around 1-5
        grads = tf.gradients(loss, dvars) # RNN
        #opt = tf.train.AdamOptimizer(learning_rate).minimize(loss, var_list=g_vars) # CNN
        opt = tf.train.AdamOptimizer(learning_rate).apply_gradients(grads_and_vars=zip(grads, dvars))
    return opt

# %%
class Model:
    def __init__(self, input_size, output_size, hidden_size, batch_size, learning_rate):

        # Data of the Model: make the data available inside the framework
        self.inputs, self.indices, self.training, cells, self.initial_state = model_input(input_size=input_size, 
                                                                                          batch_size=batch_size, 
                                                                                          hidden_size=hidden_size)
        # Create the Model: calculating the loss and forwad pass
        self.loss, self.acc = model_loss(inputs=self.inputs, indices=self.indices, batch_size=batch_size, 
                                         input_size=input_size, output_size=output_size, hidden_size=hidden_size,
                                         cells=cells, initial_state=self.initial_state, training=self.training)

        # Update the model: backward pass and backprop
        self.opt = model_opt(loss=self.loss, learning_rate=learning_rate)

# %%
graph = tf.reset_default_graph()

model = Model(input_size=input_size, hidden_size=hidden_size, output_size=output_size, 
              learning_rate=learning_rate, batch_size=batch_size)
# Out:
# (?, 8, 256, 56)
# (?, 8, 16, 2)
# (?, 1, 1, 4)
# inputs_rnn.shape, initial_state[0].shape (18, ?, 4) (18, 4)
# outputs_rnn.shape, final_state[0].shape (18, ?, 4) (18, 4)
# outputs.shape (18, 4)
# (18, 2)
# (18, 2) (?, 2)

# %%
model.inputs.shape, \
inputs_tr.shape, \
inputs_val1.shape, inputs_val2.shape, inputs_val3.shape, \
inputs_test1.shape, inputs_test2.shape, inputs_test3.shape, \
inputs_tr.reshape(18, -1, 256, 8, 56).shape, \
inputs_val1.reshape(18, -1, 256, 8, 56).shape, inputs_val2.reshape(18, -1, 256, 8, 56).shape, \
inputs_val3.reshape(18, -1, 256, 8, 56).shape, \
inputs_test1.reshape(18, -1, 256, 8, 56).shape, inputs_test2.reshape(18, -1, 256, 8, 56).shape, \
inputs_test3.reshape(18, -1, 256, 8, 56).shape, \
model.indices.shape, indices.shape
# Out:
# (TensorShape([Dimension(None), Dimension(8), Dimension(256), Dimension(56)]),
#  (720, 8, 256, 56),
#  (360, 8, 256, 56),
#  (360, 8, 256, 56),
#  (342, 8, 256, 56),
#  (702, 8, 256, 56),
#  (702, 8, 256, 56),
#  (720, 8, 256, 56),
#  (18, 40, 256, 8, 56),
#  (18, 20, 256, 8, 56),
#  (18, 20, 256, 8, 56),
#  (18, 19, 256, 8, 56),
#  (18, 39, 256, 8, 56),
#  (18, 39, 256, 8, 56),
#  (18, 40, 256, 8, 56),
#  TensorShape([Dimension(None)]),
#  (18,))

# %%
saver = tf.train.Saver()
losses_list, accs_list = [], []

with tf.Session(graph=graph) as sess:
    sess.run(fetches=tf.global_variables_initializer())
    #saver.restore(sess, 'checkpoints/model.ckpt')    
    initial_state = sess.run(model.initial_state)
    
    for epoch in range(11111):
        losses, accs = [], []
        ######################################## Training ##############################################
        loss, acc, _ = sess.run(fetches=[model.loss, model.acc, model.opt], 
                                feed_dict={model.inputs: inputs_tr, 
                                           model.indices: indices, 
                                           model.initial_state: initial_state,
                                           model.training: True})
        #print('Training loss:{:.4f}'.format(loss), 'accuracy:{:.4f}'.format(acc))
        losses.append(loss)
        accs.append(acc)
        ######################################## Validation ##############################################
        loss, acc = sess.run(fetches=[model.loss, model.acc],
                             feed_dict={model.inputs: inputs_val1, 
                                        model.indices: indices, 
                                        model.initial_state: initial_state,
                                        model.training: False})
        #print('Validation1 loss:{:.4f}'.format(loss), 'accuracy:{:.4f}'.format(acc))
        losses.append(loss)
        accs.append(acc)
        loss, acc = sess.run(fetches=[model.loss, model.acc], 
                             feed_dict={model.inputs: inputs_val2, 
                                        model.indices: indices, 
                                        model.initial_state: initial_state,
                                        model.training: False})
        #print('Validation2 loss:{:.4f}'.format(loss), 'accuracy:{:.4f}'.format(acc))
        losses.append(loss)
        accs.append(acc)
        loss, acc = sess.run(fetches=[model.loss, model.acc], 
                             feed_dict={model.inputs: inputs_val3, 
                                        model.indices: indices, 
                                        model.initial_state: initial_state,
                                        model.training: False})
        #print('Validation3 loss:{:.4f}'.format(loss), 'accuracy:{:.4f}'.format(acc))
        losses.append(loss)
        accs.append(acc)
        ######################################## Test ##############################################
        loss, acc = sess.run(fetches=[model.loss, model.acc],
                             feed_dict={model.inputs: inputs_test1, 
                                        model.indices: indices, 
                                        model.initial_state: initial_state,
                                        model.training: False})
        #print('Test1 loss:{:.4f}'.format(loss), 'accuracy:{:.4f}'.format(acc))
        losses.append(loss)
        accs.append(acc)
        loss, acc = sess.run(fetches=[model.loss, model.acc],
                             feed_dict={model.inputs: inputs_test2, 
                                        model.indices: indices, 
                                        model.initial_state: initial_state,
                                        model.training: False})
        #print('Test2 loss:{:.4f}'.format(loss), 'accuracy:{:.4f}'.format(acc))
        losses.append(loss)
        accs.append(acc)
        loss, acc = sess.run(fetches=[model.loss, model.acc],
                             feed_dict={model.inputs: inputs_test3, 
                                        model.indices: indices, 
                                        model.initial_state: initial_state,
                                        model.training: False})
        #print('Test3 loss:{:.4f}'.format(loss), 'accuracy:{:.4f}'.format(acc))
        losses.append(loss)
        accs.append(acc)
        ######################################## Saving/Printing losses/accuracies ######################
        print('Epoch:{}'.format(epoch), 'losses:', losses)
        print('Epoch:{}'.format(epoch), 'accs: ', accs)
        losses_list.append([epoch, losses])
        accs_list.append([epoch, accs])
        
    # Saving the trained model    
    saver.save(sess, 'checkpoints/model.ckpt')
# Out:
# Epoch:0 losses: [0.7635145, 0.98750335, 0.89411205, 0.91002876, 0.85945517, 0.85036117, 0.9083381]
# Epoch:0 accs:  [0.44444445, 0.5, 0.44444445, 0.5, 0.5, 0.5, 0.44444445]
# Epoch:1 losses: [0.7573646, 0.9599035, 0.8687633, 0.88835675, 0.8464686, 0.83386195, 0.8904796]
# Epoch:1 accs:  [0.44444445, 0.5, 0.5, 0.5, 0.5, 0.5, 0.44444445]
# Epoch:2 losses: [0.75148064, 0.9349447, 0.84796625, 0.8701138, 0.8346307, 0.82113314, 0.87457687]
# Epoch:2 accs:  [0.44444445, 0.5, 0.5, 0.5, 0.5, 0.5, 0.44444445]
# Epoch:16 losses: [0.69416344, 0.76067996, 0.74592876, 0.740087, 0.75274944, 0.75098634, 0.7535185]
# Epoch:16 accs:  [0.5, 0.5555556, 0.5555556, 0.33333334, 0.5, 0.5, 0.6111111]
# Epoch:17 losses: [0.69075733, 0.75555694, 0.74484503, 0.7349659, 0.749216, 0.748829, 0.751507]
# Epoch:17 accs:  [0.5, 0.6111111, 0.5555556, 0.44444445, 0.5555556, 0.5555556, 0.6111111]
# Epoch:18 losses: [0.6874294, 0.75055575, 0.743529, 0.73001534, 0.745554, 0.7465143, 0.74945694]
# Epoch:18 accs:  [0.5, 0.6111111, 0.5555556, 0.44444445, 0.5555556, 0.5555556, 0.6111111]
# Epoch:19 losses: [0.68420434, 0.74595696, 0.7422983, 0.72589666, 0.74236953, 0.7444169, 0.74764144]
# Epoch:19 accs:  [0.6111111, 0.6111111, 0.5555556, 0.44444445, 0.5, 0.5555556, 0.6111111]
# Epoch:20 losses: [0.68101096, 0.7415564, 0.74101186, 0.72210336, 0.739823, 0.74257636, 0.7458311]
# Epoch:20 accs:  [0.6111111, 0.6666667, 0.5555556, 0.44444445, 0.5, 0.6111111, 0.6666667]
# Epoch:21 losses: [0.6778524, 0.73758155, 0.73980224, 0.718727, 0.73743653, 0.74062127, 0.7439937]
# Epoch:21 accs:  [0.6111111, 0.6111111, 0.5555556, 0.5, 0.5, 0.6111111, 0.6111111]
# Epoch:22 losses: [0.67473054, 0.7345143, 0.738683, 0.7157378, 0.7352314, 0.73853886, 0.74238175]
# Epoch:22 accs:  [0.6111111, 0.6111111, 0.5, 0.5555556, 0.5555556, 0.6111111, 0.5555556]
# Epoch:23 losses: [0.67159396, 0.7321407, 0.7373965, 0.71317035, 0.73332256, 0.73665833, 0.7409289]
# Epoch:23 accs:  [0.6111111, 0.6111111, 0.44444445, 0.5555556, 0.5555556, 0.6111111, 0.5555556]
# Epoch:24 losses: [0.6684654, 0.7300685, 0.7360866, 0.71085423, 0.7315704, 0.73495096, 0.7395972]
# Epoch:24 accs:  [0.6111111, 0.6111111, 0.5, 0.5555556, 0.5555556, 0.6111111, 0.6111111]
# Epoch:25 losses: [0.6653251, 0.7285546, 0.73487514, 0.7088661, 0.73007613, 0.733454, 0.7384765]
# Epoch:25 accs:  [0.6111111, 0.5555556, 0.5, 0.6111111, 0.5555556, 0.6111111, 0.5555556]
# Epoch:26 losses: [0.6621701, 0.72750366, 0.7336935, 0.70726883, 0.7288883, 0.73220325, 0.7374966]
# Epoch:26 accs:  [0.6111111, 0.5555556, 0.5555556, 0.6111111, 0.5555556, 0.6111111, 0.6111111]
# Epoch:27 losses: [0.6590448, 0.72659934, 0.732476, 0.70591944, 0.7279403, 0.7311939, 0.73652047]
# Epoch:27 accs:  [0.6111111, 0.5555556, 0.5, 0.6666667, 0.5555556, 0.6111111, 0.6111111]
# Epoch:28 losses: [0.65592957, 0.7259595, 0.73138833, 0.70484287, 0.72724545, 0.7303822, 0.73571545]
# Epoch:28 accs:  [0.6111111, 0.5555556, 0.5, 0.6666667, 0.5555556, 0.6111111, 0.6111111]
# Epoch:29 losses: [0.6527631, 0.72545487, 0.73045766, 0.7039251, 0.7266855, 0.72958314, 0.7349822]
# Epoch:29 accs:  [0.6111111, 0.5555556, 0.44444445, 0.6666667, 0.5555556, 0.6111111, 0.5555556]
# Epoch:30 losses: [0.6496657, 0.72502476, 0.72952586, 0.70315504, 0.7262069, 0.7288486, 0.7341548]
# Epoch:30 accs:  [0.6666667, 0.5555556, 0.44444445, 0.6666667, 0.5555556, 0.6111111, 0.5555556]
# Epoch:31 losses: [0.64655906, 0.7247057, 0.72861874, 0.702531, 0.7258022, 0.7281743, 0.7332618]
# Epoch:31 accs:  [0.6666667, 0.5555556, 0.44444445, 0.6666667, 0.5555556, 0.6111111, 0.5555556]
# Epoch:32 losses: [0.6436155, 0.72456735, 0.7276862, 0.701958, 0.7254409, 0.72753304, 0.73236704]
# Epoch:32 accs:  [0.6666667, 0.5555556, 0.44444445, 0.6666667, 0.5555556, 0.6111111, 0.5555556]
# Epoch:33 losses: [0.6407298, 0.72447705, 0.72674966, 0.7014145, 0.72502965, 0.7269386, 0.7313483]
# Epoch:33 accs:  [0.6666667, 0.5555556, 0.44444445, 0.6666667, 0.5555556, 0.6111111, 0.5555556]
# Epoch:34 losses: [0.63796544, 0.72432923, 0.7258207, 0.70089734, 0.7246139, 0.7263699, 0.7302065]
# Epoch:34 accs:  [0.6666667, 0.5555556, 0.44444445, 0.6666667, 0.5555556, 0.6111111, 0.5555556]
# Epoch:35 losses: [0.63514876, 0.72405446, 0.72491336, 0.7003012, 0.72414273, 0.7257727, 0.7290389]
# Epoch:35 accs:  [0.6666667, 0.5555556, 0.5, 0.6666667, 0.5555556, 0.6111111, 0.5555556]
# Epoch:36 losses: [0.63231635, 0.7237427, 0.72399753, 0.699582, 0.7237076, 0.7251632, 0.72795254]
# Epoch:36 accs:  [0.6666667, 0.5555556, 0.5, 0.6111111, 0.5555556, 0.6111111, 0.5555556]
# Epoch:37 losses: [0.62943375, 0.7232685, 0.7230587, 0.69888765, 0.7233038, 0.72450185, 0.7268524]
# Epoch:37 accs:  [0.6666667, 0.5555556, 0.5, 0.6111111, 0.6111111, 0.6666667, 0.5555556]
# Epoch:38 losses: [0.62651753, 0.7225875, 0.7221004, 0.69810796, 0.72279835, 0.7237389, 0.72573894]
# Epoch:38 accs:  [0.6666667, 0.5555556, 0.5, 0.6111111, 0.6111111, 0.6666667, 0.5]
# Epoch:39 losses: [0.62357765, 0.7217323, 0.7210331, 0.697264, 0.7221868, 0.7228805, 0.72455204]
# Epoch:39 accs:  [0.6666667, 0.5555556, 0.5, 0.5555556, 0.6666667, 0.6666667, 0.5]
# Epoch:40 losses: [0.6207037, 0.72084963, 0.71977097, 0.6963475, 0.72147405, 0.7219126, 0.7231954]
# Epoch:40 accs:  [0.6666667, 0.5555556, 0.5, 0.5555556, 0.6666667, 0.6666667, 0.5555556]
# Epoch:41 losses: [0.6179597, 0.719781, 0.718352, 0.69550544, 0.7208365, 0.7209399, 0.7216256]
accs:  [0.9444444, 0.7222222, 0.6666667, 0.6111111, 0.7222222, 0.6666667, 0.6666667]
# Epoch:174 losses: [0.38541758, 0.56482536, 0.5833861, 0.59934723, 0.5681655, 0.57736874, 0.5622388]
# Epoch:174 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6111111, 0.7222222, 0.6666667, 0.6666667]
# Epoch:175 losses: [0.38417885, 0.56395054, 0.58287835, 0.59919345, 0.5673433, 0.5766603, 0.56165075]
# Epoch:175 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6111111, 0.7222222, 0.6666667, 0.6666667]
# Epoch:176 losses: [0.38288525, 0.56248426, 0.5818888, 0.5983612, 0.56594366, 0.5753946, 0.56041104]
# Epoch:176 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6111111, 0.7222222, 0.6666667, 0.6666667]
# Epoch:177 losses: [0.381677, 0.56068724, 0.5806091, 0.5970923, 0.5641501, 0.5737603, 0.5588628]
# Epoch:177 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6111111, 0.7222222, 0.6666667, 0.7222222]
# Epoch:178 losses: [0.3805087, 0.55889976, 0.5791595, 0.59576184, 0.56226814, 0.57201743, 0.5572932]
# Epoch:178 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6666667, 0.7222222, 0.6666667, 0.7222222]
# Epoch:179 losses: [0.37939945, 0.5575924, 0.5780409, 0.5948809, 0.5609004, 0.57072943, 0.5560999]
# Epoch:179 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6666667, 0.7222222, 0.6666667, 0.7222222]
# Epoch:180 losses: [0.37830862, 0.5568116, 0.57737917, 0.594522, 0.5600995, 0.5699204, 0.55539566]
# Epoch:180 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6666667, 0.7222222, 0.6666667, 0.7222222]
# Epoch:181 losses: [0.37720838, 0.555537, 0.57625085, 0.5935456, 0.5586392, 0.56848735, 0.5541101]
# Epoch:181 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6666667, 0.7222222, 0.6666667, 0.7222222]
# Epoch:182 losses: [0.3760692, 0.5537909, 0.57470924, 0.59195876, 0.556539, 0.56645244, 0.5522973]
# Epoch:182 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6666667, 0.7222222, 0.6666667, 0.7222222]
# Epoch:183 losses: [0.37491983, 0.55169845, 0.5728913, 0.5899464, 0.55401015, 0.5639892, 0.55008036]
# Epoch:183 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6666667, 0.7222222, 0.6666667, 0.7222222]
# Epoch:184 losses: [0.37382305, 0.55010873, 0.5715843, 0.5886249, 0.55217904, 0.562166, 0.5484077]
# Epoch:184 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6666667, 0.7222222, 0.6666667, 0.7222222]
# Epoch:185 losses: [0.37273383, 0.54881257, 0.57061553, 0.587833, 0.55085105, 0.56084657, 0.54713166]
# Epoch:185 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6111111, 0.7222222, 0.6666667, 0.7222222]
# Epoch:186 losses: [0.37164965, 0.5478804, 0.57000583, 0.5876256, 0.5502074, 0.5601646, 0.54638153]
# Epoch:186 accs:  [0.9444444, 0.7222222, 0.6666667, 0.6111111, 0.7222222, 0.6666667, 0.7222222]
# Epoch:187 losses: [0.37054718, 0.5472875, 0.5696872, 0.58782303, 0.54998285, 0.55994517, 0.5459607]
# Epoch:187 accs:  [0.9444444, 0.7222222, 0.6666667, 0.5555556, 0.7222222, 0.6666667, 0.7222222]
# Epoch:188 losses: [0.36944765, 0.54695255, 0.56962967, 0.5883605, 0.55016285, 0.56018054, 0.5458035]
# Epoch:188 accs:  [0.9444444, 0.7222222, 0.6666667, 0.5555556, 0.7222222, 0.6666667, 0.7222222]
# Epoch:189 losses: [0.36834723, 0.54675645, 0.5697524, 0.5891522, 0.5506476, 0.5607575, 0.54586244]
# Epoch:189 accs:  [0.9444444, 0.7222222, 0.6666667, 0.5555556, 0.7222222, 0.6111111, 0.6666667]
# Epoch:190 losses: [0.36724812, 0.54614383, 0.56952477, 0.58941543, 0.55055463, 0.5607482, 0.54547054]
# Epoch:190 accs:  [0.9444444, 0.7222222, 0.6666667, 0.5555556, 0.7222222, 0.6111111, 0.6666667]
# Epoch:191 losses: [0.3662012, 0.54402566, 0.56790996, 0.5876707, 0.5484213, 0.55861485, 0.54340637]
# Epoch:191 accs:  [0.9444444, 0.7222222, 0.6666667, 0.5555556, 0.7222222, 0.6111111, 0.6666667]
# Epoch:192 losses: [0.36512196, 0.54165983, 0.56597894, 0.58550215, 0.5458421, 0.555984, 0.5409801]
# Epoch:192 accs:  [0.9444444, 0.7222222, 0.6666667, 0.5555556, 0.7222222, 0.6111111, 0.7222222]
# Epoch:193 losses: [0.3640513, 0.53910094, 0.5638449, 0.5830554, 0.5430219, 0.55307424, 0.5382942]
# Epoch:193 accs:  [1.0, 0.7222222, 0.6666667, 0.5555556, 0.7222222, 0.6111111, 0.7222222]
# Epoch:194 losses: [0.3629879, 0.5369967, 0.5620637, 0.5812614, 0.5408317, 0.5508151, 0.5360463]
# Epoch:194 accs:  [1.0, 0.7222222, 0.6666667, 0.6111111, 0.7222222, 0.6111111, 0.7222222]
# Epoch:195 losses: [0.36195895, 0.53575635, 0.56108177, 0.5803512, 0.53970915, 0.5495957, 0.53474224]
# Epoch:195 accs:  [1.0, 0.7222222, 0.6666667, 0.6111111, 0.6666667, 0.6111111, 0.7222222]
# Epoch:196 losses: [0.3609515, 0.53529376, 0.56086814, 0.5801688, 0.5394903, 0.5492399, 0.5343096]
# Epoch:196 accs:  [1.0, 0.7222222, 0.6666667, 0.5555556, 0.6666667, 0.6111111, 0.7222222]
# Epoch:197 losses: [0.3599313, 0.535564, 0.5614288, 0.58081675, 0.5401831, 0.5498279, 0.5347493]
# Epoch:197 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.7222222]
# Epoch:198 losses: [0.3589069, 0.5363841, 0.56258416, 0.5821767, 0.54158086, 0.5512093, 0.5357146]
# Epoch:198 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.7222222]
# Epoch:199 losses: [0.35791934, 0.5370201, 0.563483, 0.58312476, 0.54272527, 0.55219626, 0.5363797]
# Epoch:199 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.6666667]
# Epoch:200 losses: [0.3569382, 0.5373796, 0.5639937, 0.583616, 0.5434631, 0.55267686, 0.536658]
# Epoch:200 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.6666667]
# Epoch:201 losses: [0.3559774, 0.53677726, 0.5635637, 0.5829456, 0.5430066, 0.5518954, 0.53597385]
# Epoch:201 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.6666667]
# Epoch:202 losses: [0.35501686, 0.53513485, 0.5621655, 0.58120453, 0.5414227, 0.5499652, 0.5343052]
# Epoch:202 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.7222222]
# Epoch:203 losses: [0.3540755, 0.5336711, 0.5609565, 0.5799229, 0.54024965, 0.54850745, 0.5328553]
# Epoch:203 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.7222222]
# Epoch:204 losses: [0.35315114, 0.53252155, 0.5601157, 0.57920015, 0.5396074, 0.5475929, 0.53181976]
# Epoch:204 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.7222222]
# Epoch:205 losses: [0.352228, 0.53186417, 0.5598387, 0.57916784, 0.5396226, 0.5473232, 0.53140414]
# Epoch:205 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.7222222]
# Epoch:206 losses: [0.3513041, 0.53178316, 0.5601232, 0.5798449, 0.5403726, 0.5477919, 0.5316215]
# Epoch:206 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.7222222]
# Epoch:207 losses: [0.35037702, 0.53179073, 0.5604844, 0.5806033, 0.54117835, 0.5483534, 0.5319402]
# Epoch:207 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.7222222]
# Epoch:208 losses: [0.3494677, 0.5317861, 0.56092465, 0.5813541, 0.5419718, 0.5489124, 0.5323136]
# Epoch:208 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.6666667]
# Epoch:209 losses: [0.3485621, 0.5318609, 0.5615152, 0.5821973, 0.5428097, 0.549552, 0.5328208]
# Epoch:209 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.6666667]
# Epoch:210 losses: [0.34766135, 0.5321761, 0.56236124, 0.58324516, 0.5438922, 0.550459, 0.53366727]
# Epoch:210 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.6666667]
# Epoch:211 losses: [0.34677112, 0.5318165, 0.5625805, 0.5834748, 0.54414886, 0.55055666, 0.53383595]
# Epoch:211 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.6666667]
# Epoch:212 losses: [0.34588563, 0.5308913, 0.56211245, 0.5829295, 0.5436313, 0.54989886, 0.5332839]
# Epoch:212 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.6666667]
# Epoch:213 losses: [0.3450159, 0.53117144, 0.5628261, 0.5835675, 0.5443677, 0.550507, 0.533996]
# Epoch:213 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6666667, 0.6111111, 0.6666667]
# Epoch:214 losses: [0.34413707, 0.53220797, 0.5642553, 0.58500594, 0.5458877, 0.55195, 0.53548396]
# Epoch:214 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6666667]
# Epoch:215 losses: [0.34326285, 0.53360564, 0.56601214, 0.5868907, 0.54784024, 0.5538653, 0.53734636]
# Epoch:215 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6666667]
# Epoch:216 losses: [0.34239393, 0.5344832, 0.5671239, 0.58814555, 0.5491339, 0.5552124, 0.5385572]
# Epoch:216 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6666667]
# Epoch:217 losses: [0.34153605, 0.5347331, 0.5675767, 0.58878046, 0.5497391, 0.5559195, 0.53907996]
# Epoch:217 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6666667]
# Epoch:218 losses: [0.34068462, 0.5352791, 0.5683737, 0.589921, 0.5508249, 0.557173, 0.5399707]
# Epoch:218 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6666667]
# Epoch:219 losses: [0.33983678, 0.53519785, 0.568529, 0.5903986, 0.551186, 0.5576882, 0.5401806]
# Epoch:219 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6666667]
# Epoch:220 losses: [0.33900046, 0.5350331, 0.5685523, 0.5906804, 0.5514095, 0.5580623, 0.5402456]
# Epoch:220 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6111111]
# Epoch:221 losses: [0.33817002, 0.533796, 0.5675339, 0.58972424, 0.55030197, 0.55702573, 0.5391679]
# Epoch:221 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6111111]
# Epoch:222 losses: [0.3373516, 0.53340507, 0.56740785, 0.5898497, 0.5503395, 0.55723053, 0.5390129]
# Epoch:222 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6111111]
# Epoch:223 losses: [0.3365293, 0.5337774, 0.5681082, 0.59093624, 0.55139583, 0.558506, 0.53971267]
# Epoch:223 accs:  [1.0, 0.6666667, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6111111]
# Epoch:224 losses: [0.33570725, 0.53383917, 0.5684849, 0.5916174, 0.5520468, 0.5592873, 0.5400572]
# Epoch:224 accs:  [1.0, 0.6666667, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6111111]
# Epoch:225 losses: [0.33490553, 0.53281784, 0.5677086, 0.59092176, 0.55116785, 0.5584672, 0.53921443]
# Epoch:225 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6111111]
# Epoch:226 losses: [0.33410054, 0.5307653, 0.56584567, 0.5890372, 0.5488839, 0.5561827, 0.53725934]
# Epoch:226 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6111111]
# Epoch:227 losses: [0.33329624, 0.529166, 0.5645637, 0.587974, 0.54745895, 0.5547991, 0.53590417]
# Epoch:227 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6111111]
# Epoch:228 losses: [0.33250645, 0.5286812, 0.56455475, 0.5882113, 0.5474926, 0.5549576, 0.53585094]
# Epoch:228 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6111111]
# Epoch:229 losses: [0.3317108, 0.52961814, 0.566194, 0.5900408, 0.5493842, 0.55703855, 0.53746194]
# Epoch:229 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:230 losses: [0.330924, 0.53038216, 0.56759334, 0.5916485, 0.55104303, 0.55879664, 0.5388022]
# Epoch:230 accs:  [1.0, 0.6666667, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:231 losses: [0.33015132, 0.5292992, 0.56694406, 0.5908649, 0.550093, 0.5578514, 0.53806275]
# Epoch:231 accs:  [1.0, 0.6666667, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:232 losses: [0.32938722, 0.52481544, 0.5627273, 0.58645135, 0.5451213, 0.552676, 0.53365093]
# Epoch:232 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:233 losses: [0.3286249, 0.5223567, 0.56063676, 0.58425957, 0.54276234, 0.55017346, 0.5314243]
# Epoch:233 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.6111111]
# Epoch:234 losses: [0.32789314, 0.52247316, 0.5612804, 0.58469635, 0.543455, 0.5508964, 0.5320283]
# Epoch:234 accs:  [1.0, 0.7222222, 0.6111111, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:235 losses: [0.32710484, 0.5250666, 0.56456745, 0.58762234, 0.54704773, 0.5546198, 0.5353062]
# Epoch:235 accs:  [1.0, 0.7222222, 0.5555556, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:236 losses: [0.32629874, 0.52906173, 0.56924903, 0.5918078, 0.5521519, 0.5597462, 0.5400002]
# Epoch:236 accs:  [1.0, 0.6666667, 0.5555556, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:237 losses: [0.3255219, 0.53088826, 0.5715015, 0.59385383, 0.55459255, 0.56216425, 0.54227674]
# Epoch:237 accs:  [1.0, 0.6666667, 0.5555556, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:238 losses: [0.32478264, 0.5274427, 0.5690986, 0.5913341, 0.55150974, 0.55900437, 0.5396031]
# Epoch:238 accs:  [1.0, 0.6666667, 0.5555556, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:239 losses: [0.32395974, 0.52306545, 0.56539226, 0.5876677, 0.54717517, 0.55455995, 0.5356273]
# Epoch:239 accs:  [1.0, 0.6666667, 0.5555556, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:240 losses: [0.3232025, 0.52150774, 0.5644971, 0.58665633, 0.54602265, 0.55325854, 0.534569]
# Epoch:240 accs:  [1.0, 0.7222222, 0.5555556, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:241 losses: [0.32244775, 0.52268803, 0.5663954, 0.5882089, 0.54787064, 0.5550311, 0.5364406]
# Epoch:241 accs:  [1.0, 0.6666667, 0.5555556, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:242 losses: [0.32165614, 0.5258415, 0.570296, 0.5916391, 0.55193835, 0.55898124, 0.540424]
# Epoch:242 accs:  [1.0, 0.6666667, 0.5555556, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch:243 losses: [0.32087883, 0.52761275, 0.57259154, 0.59356487, 0.55436844, 0.56125605, 0.5427617]
# Epoch:243 accs:  [1.0, 0.6666667, 0.5555556, 0.5555556, 0.6111111, 0.6111111, 0.5555556]
# Epoch
accs:  [1.0, 1.0, 1.0, 0.9444444, 1.0, 0.9444444, 1.0]
# Epoch:989 losses: [0.07442938, 0.24958055, 0.28553635, 0.32355917, 0.24429083, 0.2508581, 0.22888997]
# Epoch:989 accs:  [1.0, 1.0, 1.0, 0.9444444, 1.0, 0.9444444, 1.0]
# Epoch:990 losses: [0.07431074, 0.24975048, 0.2869028, 0.32471356, 0.24537165, 0.25205934, 0.23046544]
# Epoch:990 accs:  [1.0, 1.0, 1.0, 0.9444444, 1.0, 0.9444444, 1.0]
# Epoch:991 losses: [0.074194446, 0.24963641, 0.2865222, 0.32458138, 0.24513537, 0.25175536, 0.22993506]
# Epoch:991 accs:  [1.0, 1.0, 1.0, 0.9444444, 1.0, 0.9444444, 1.0]
# Epoch:992 losses: [0.0740795, 0.24936236, 0.28547293, 0.32355177, 0.244257, 0.25078306, 0.2286441]
# Epoch:992 accs:  [1.0, 1.0, 1.0, 0.8888889, 1.0, 0.9444444, 1.0]
# Epoch:993 losses: [0.07396318, 0.24905126, 0.28457245, 0.32295164, 0.24354492, 0.24994537, 0.22762606]
# Epoch:993 accs:  [1.0, 1.0, 1.0, 0.8888889, 1.0, 0.9444444, 1.0]
# Epoch:994 losses: [0.07384943, 0.24892956, 0.28529823, 0.3229264, 0.24388017, 0.25049457, 0.22857979]
# Epoch:994 accs:  [1.0, 1.0, 1.0, 0.9444444, 1.0, 0.9444444, 1.0]
# Epoch:995 losses: [0.07373125, 0.24900764, 0.28734905, 0.32410365, 0.24532747, 0.25218785, 0.23106517]
# Epoch:995 accs:  [1.0, 1.0, 1.0, 0.9444444, 1.0, 0.9444444, 1.0]
# Epoch:996 losses: [0.07361929, 0.24881665, 0.287167, 0.32378194, 0.2452267, 0.25205475, 0.2308997]
# Epoch:996 accs:  [1.0, 1.0, 1.0, 0.9444444, 1.0, 0.9444444, 1.0]
# Epoch:997 losses: [0.07350212, 0.24847692, 0.28527772, 0.32274675, 0.24402653, 0.25054866, 0.22868317]
# Epoch:997 accs:  [1.0, 1.0, 1.0, 0.9444444, 1.0, 0.9444444, 1.0]
# Epoch:998 losses: [0.073381454, 0.2480634, 0.28329077, 0.3215892, 0.24278228, 0.2489276, 0.22630824]
# Epoch:998 accs:  [1.0, 1.0, 1.0, 0.8888889, 1.0, 0.9444444, 1.0]
# Epoch:999 losses: [0.073270276, 0.2478841, 0.28307196, 0.32138932, 0.24265736, 0.2487354, 0.22603825]
# Epoch:999 accs:  [1.0, 1.0, 1.0, 0.8888889, 1.0, 0.9444444, 1.0]
# Epoch:1000 losses: [0.07315631, 0.24783628, 0.28392988, 0.3216399, 0.24315275, 0.24939919, 0.22707224]
# Epoch:1000 accs:  [1.0, 1.0, 1.0, 0.8888889, 1.0, 0.9444444, 1.0]
# Epoch:1001 losses: [0.07304037, 0.24770927, 0.2843064, 0.32152694, 0.2432611, 0.24958318, 0.22754377]
# Epoch:1001 accs:  [1.0, 1.0, 1.0, 0.8888889, 1.0, 0.9444444, 1.0]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
for idx in range(len(losses_list[0][1])):
    loss = [[each[0], each[1][idx]] for each in losses_list]
    eps, arr = np.array(loss).T
    smoothed_arr = running_mean(arr, 10)
    plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
    plt.plot(eps, arr, color='grey', alpha=0.3)
    plt.xlabel('Episode')
    plt.ylabel('Loss')
#     plt.legend('Loss{}'.format(idx))
#     plt.show()

# %%
for idx in range(len(losses_list[0][1])):
    acc = [[each[0], each[1][idx]] for each in accs_list]
    eps, arr = np.array(acc).T
    smoothed_arr = running_mean(arr, 10)
    plt.plot(eps[-len(smoothed_arr):], smoothed_arr)
    plt.plot(eps, arr, color='grey', alpha=0.3)
    plt.xlabel('Episode')
    plt.ylabel('Acc')
